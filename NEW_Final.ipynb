# %%
import pandas as pd

# %%
shop=pd.read_csv("Data/NewShopping_Data.csv")
shop1=pd.read_csv("Data/NewShopping.csv")
med=pd.read_csv('Data/NewMedical.csv')
stat=pd.read_csv('Data/Stationary.csv')
elec=pd.read_csv('Data/electronics.csv' ,encoding='latin-1')
grocery=pd.read_csv('Data/NewGrocery.csv')
food=pd.read_csv('Data/NewFood.csv')

# %%
shop_final= pd.concat((shop,shop1,med,stat,elec,grocery,food),axis=0,ignore_index=True)

# %%
shop_final
# Out:
#                                                   Name       Long        Lat  \
# 0                                   Aadhar Seva Kendra  19.383637  72.825737
# 1                                VVMC Municipal Office  19.400958  72.843473
# 2                          Welkin International School  19.401474  72.828918
# 3                                       Talathi Office  19.360752  72.797552
# 4    Vasai Virar City Municipal Corporation (Prabha...  19.421743  72.817150
# ..                                                 ...        ...        ...
# 628                          Chaitanya's BIRYANI HOUSE  19.385227  72.823851
# 629                                      DON MISALWALE  19.385389  72.824409
# 630                                      Bhukkad_Mafia  19.386361  72.823765
# 631                                Jagdamba Chaat Wala  19.379276  72.829473
# 632                                        Zeal Skybar  19.366578  72.815509
#
#      Rating    Type
# 0       1.0     Gov
# 1       1.8     Gov
# 2       2.0  School
# 3       2.0     Gov
# 4       2.7     Gov
# ..      ...     ...
# 628     5.0    Food
# 629     4.0    Food
# 630     4.0    Food
# 631     3.0    Food
# 632     4.0    Food
#
# [633 rows x 5 columns]

# %%
shop_final.columns
# Out:
# Index(['Name', 'Long', 'Lat', 'Rating', 'Type'], dtype='object')

# %%
datamapping= {
    "School" : 1,
    "Gym" : 2,
    "Gov" : 3,
    "Shopping" : 4,
    "Medical" : 5,
    "Stationary" : 6,
    "Electronics" : 7,
    "Grocery" : 8,
    "Food":9
}

# %%
df=shop_final

# %%
df['Type'] = df['Type'].map(datamapping)

# %%
df
# Out:
#                                                   Name       Long        Lat  \
# 0                                   Aadhar Seva Kendra  19.383637  72.825737
# 1                                VVMC Municipal Office  19.400958  72.843473
# 2                          Welkin International School  19.401474  72.828918
# 3                                       Talathi Office  19.360752  72.797552
# 4    Vasai Virar City Municipal Corporation (Prabha...  19.421743  72.817150
# ..                                                 ...        ...        ...
# 628                          Chaitanya's BIRYANI HOUSE  19.385227  72.823851
# 629                                      DON MISALWALE  19.385389  72.824409
# 630                                      Bhukkad_Mafia  19.386361  72.823765
# 631                                Jagdamba Chaat Wala  19.379276  72.829473
# 632                                        Zeal Skybar  19.366578  72.815509
#
#      Rating  Type
# 0       1.0     3
# 1       1.8     3
# 2       2.0     1
# 3       2.0     3
# 4       2.7     3
# ..      ...   ...
# 628     5.0     9
# 629     4.0     9
# 630     4.0     9
# 631     3.0     9
# 632     4.0     9
#
# [633 rows x 5 columns]

# %%
df.isnull().sum()
# Out:
# Name      0
# Long      0
# Lat       0
# Rating    0
# Type      0
# dtype: int64

# %%
import folium

m = folium.Map(location=[19.383923, 72.829269], zoom_start=13)

folium.Marker([19.383923, 72.829269]).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6f54afa6626272ad61aafd78d2e75ea9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6f54afa6626272ad61aafd78d2e75ea9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6f54afa6626272ad61aafd78d2e75ea9 = L.map(
#                 &quot;map_6f54afa6626272ad61aafd78d2e75ea9&quot;,
#                 {
#                     center: [19.383923, 72.829269],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_46bb180f3e7d398ffe8ead4261f47893 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_6f54afa6626272ad61aafd78d2e75ea9);
#
#
#             var marker_e3d3f0b05dd609326c52aa6fdbf6ca8a = L.marker(
#                 [19.383923, 72.829269],
#                 {}
#             ).addTo(map_6f54afa6626272ad61aafd78d2e75ea9);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
df
# Out:
#                                                   Name       Long        Lat  \
# 0                                   Aadhar Seva Kendra  19.383637  72.825737
# 1                                VVMC Municipal Office  19.400958  72.843473
# 2                          Welkin International School  19.401474  72.828918
# 3                                       Talathi Office  19.360752  72.797552
# 4    Vasai Virar City Municipal Corporation (Prabha...  19.421743  72.817150
# ..                                                 ...        ...        ...
# 628                          Chaitanya's BIRYANI HOUSE  19.385227  72.823851
# 629                                      DON MISALWALE  19.385389  72.824409
# 630                                      Bhukkad_Mafia  19.386361  72.823765
# 631                                Jagdamba Chaat Wala  19.379276  72.829473
# 632                                        Zeal Skybar  19.366578  72.815509
#
#      Rating  Type
# 0       1.0     3
# 1       1.8     3
# 2       2.0     1
# 3       2.0     3
# 4       2.7     3
# ..      ...   ...
# 628     5.0     9
# 629     4.0     9
# 630     4.0     9
# 631     3.0     9
# 632     4.0     9
#
# [633 rows x 5 columns]

# %%
df.columns
# Out:
# Index(['Name', 'Long', 'Lat', 'Rating', 'Type'], dtype='object')

# %%
df = df.astype({'Rating':'float'})

# %%
df = df.astype({'Rating':'int'})

# %%
df.shape
# Out:
# (633, 5)

# %%
def map(school,gym,gov,shopping,medical,stationary,Electronics,Grocery,Food):
 name1=df['Name']
 long = df['Long']
 lat = df['Lat']
 rat=df['Rating'].astype(int)
 tar = df['Type']
 fg=folium.FeatureGroup(name="any")
 m = folium.Map(location=[19.383923, 72.829269], zoom_start=30)

 for i in range(633):
  tarvalue=tar[i]
  if school == 1 and tarvalue== 1 :
    if rat[i] > 4 : 
      fg.add_child(folium.Marker([long[i],lat[i]],popup=name1[i],icon=folium.Icon(color='darkgreen')))
    elif rat[i] > 3 : 
      fg.add_child(folium.Marker([long[i],lat[i]],popup=name1[i],icon=folium.Icon(color='green')))
    else :
      fg.add_child(folium.Marker([long[i],lat[i]],popup=name1[i],icon=folium.Icon(color='lightgreen')))
  if gym == 1 and tarvalue ==2 :
    if rat[i] > 4 : 
      fg.add_child(folium.Marker([long[i],lat[i]],popup=name1[i],icon=folium.Icon(color='darkred')))
    elif rat[i] > 3 : 
      fg.add_child(folium.Marker([long[i],lat[i]],popup=name1[i],icon=folium.Icon(color='red')))
    else :
      fg.add_child(folium.Marker([long[i],lat[i]],popup=name1[i],icon=folium.Icon(color='lightred')))
  if gov == 1 and tarvalue == 3 : 
    if rat[i] > 4 : 
      fg.add_child(folium.Marker([long[i],lat[i]],popup=name1[i],icon=folium.Icon(color='darkblue')))
    elif rat[i] > 3 : 
      fg.add_child(folium.Marker([long[i],lat[i]],popup=name1[i],icon=folium.Icon(color='blue')))
    else :
      fg.add_child(folium.Marker([long[i],lat[i]],popup=name1[i],icon=folium.Icon(color='lightblue')))
  if shopping == 1 and tarvalue ==4 :
    if rat[i] > 4 : 
      fg.add_child(folium.Marker([long[i],lat[i]],popup=name1[i],icon=folium.Icon(color='black')))
    elif rat[i] > 3 : 
      fg.add_child(folium.Marker([long[i],lat[i]],popup=name1[i],icon=folium.Icon(color='gray')))
    else :
      fg.add_child(folium.Marker([long[i],lat[i]],popup=name1[i],icon=folium.Icon(color='lightgray')))
  if medical == 1 and tarvalue == 5 :
    if rat[i] > 4 : 
      fg.add_child(folium.Marker([long[i],lat[i]],popup=name1[i],icon=folium.Icon(color='darkpurple')))
    elif rat[i] > 3 : 
      fg.add_child(folium.Marker([long[i],lat[i]],popup=name1[i],icon=folium.Icon(color='darkpurple')))
    else :
      fg.add_child(folium.Marker([long[i],lat[i]],popup=name1[i],icon=folium.Icon(color='purple')))
  if stationary == 1 and tarvalue == 6 :
    if rat[i] > 4 : 
      fg.add_child(folium.Marker([long[i],lat[i]],popup=name1[i],icon=folium.Icon(color='lightpink')))
    elif rat[i] > 3 : 
      fg.add_child(folium.Marker([long[i],lat[i]],popup=name1[i],icon=folium.Icon(color='lightpink')))
    else :
      fg.add_child(folium.Marker([long[i],lat[i]],popup=name1[i],icon=folium.Icon(color='pink')))
  if Electronics == 1 and tarvalue == 7 :
    if rat[i] > 4 : 
      fg.add_child(folium.Marker([long[i],lat[i]],popup=name1[i],icon=folium.Icon(color='darkorange')))
    elif rat[i] > 3 : 
      fg.add_child(folium.Marker([long[i],lat[i]],popup=name1[i],icon=folium.Icon(color='orange')))
    else :
      fg.add_child(folium.Marker([long[i],lat[i]],popup=name1[i],icon=folium.Icon(color='orange')))
  if Grocery == 1 and tarvalue == 8 : 
      fg.add_child(folium.Marker([long[i],lat[i]],popup=name1[i],icon=folium.Icon(color='beige')))
  if Food == 1 and tarvalue == 9 : 
      fg.add_child(folium.Marker([long[i],lat[i]],popup=name1[i],icon=folium.Icon(color='cadetblue')))
    
 return m.add_child(fg)

# %%
map(0,0,0,0,0,0,0,0,1)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b6d88b08b6bc88c85c95c8bdd41bf6f1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b6d88b08b6bc88c85c95c8bdd41bf6f1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b6d88b08b6bc88c85c95c8bdd41bf6f1 = L.map(
#                 &quot;map_b6d88b08b6bc88c85c95c8bdd41bf6f1&quot;,
#                 {
#                     center: [19.383923, 72.829269],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 30,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_822e4f809ae2c2c0fa901f4e84001d92 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_b6d88b08b6bc88c85c95c8bdd41bf6f1);
#
#
#             var feature_group_6a2ece9af70b116023b63e169e89d1dc = L.featureGroup(
#                 {}
#             ).addTo(map_b6d88b08b6bc88c85c95c8bdd41bf6f1);
#
#
#             var marker_090be6bedc1c976b0f0088410d969bd9 = L.marker(
#                 [19.3839229, 72.82926931],
#                 {}
#             ).addTo(feature_group_6a2ece9af70b116023b63e169e89d1dc);
#
#
#             var icon_fb015c737f7741d32cd02c80088e268d = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;cadetblue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_090be6bedc1c976b0f0088410d969bd9.setIcon(icon_fb015c737f7741d32cd02c80088e268d);
#
#
#         var popup_ce52b41f7a3ee4fd4af6dcee132583d8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0004dff82527847ff857f65e89a28e68 = $(`&lt;div id=&quot;html_0004dff82527847ff857f65e89a28e68&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Nature&#x27;s Fuel &amp; Foodzone&lt;/div&gt;`)[0];
#                 popup_ce52b41f7a3ee4fd4af6dcee132583d8.setContent(html_0004dff82527847ff857f65e89a28e68);
#
#
#
#         marker_090be6bedc1c976b0f0088410d969bd9.bindPopup(popup_ce52b41f7a3ee4fd4af6dcee132583d8)
#         ;
#
#
#
#
#             var marker_41505e2f3afa11d5cd5321079346086c = L.marker(
#                 [19.38386217, 72.82926462],
#                 {}
#             ).addTo(feature_group_6a2ece9af70b116023b63e169e89d1dc);
#
#
#             var icon_3df131e130e4e9e83fa6e25f061f742d = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;cadetblue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_41505e2f3afa11d5cd5321079346086c.setIcon(icon_3df131e130e4e9e83fa6e25f061f742d);
#
#
#         var popup_60979096ab680c7569d1dbb6198e6e4c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_40c2b36d86423b68b3186f7eafd3d652 = $(`&lt;div id=&quot;html_40c2b36d86423b68b3186f7eafd3d652&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Pic A Bite - Vartak Branch&lt;/div&gt;`)[0];
#                 popup_60979096ab680c7569d1dbb6198e6e4c.setContent(html_40c2b36d86423b68b3186f7eafd3d652);
#
#
#
#         marker_41505e2f3afa11d5cd5321079346086c.bindPopup(popup_60979096ab680c7569d1dbb6198e6e4c)
#         ;
#
#
#
#
#             var marker_c6d8c2f5cb3c67805d65f0329be8fc8b = L.marker(
#                 [19.38423537, 72.82956771],
#                 {}
#             ).addTo(feature_group_6a2ece9af70b116023b63e169e89d1dc);
#
#
#             var icon_9561601b3a4192de3c4cd3abd721fba7 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;cadetblue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_c6d8c2f5cb3c67805d65f0329be8fc8b.setIcon(icon_9561601b3a4192de3c4cd3abd721fba7);
#
#
#         var popup_9eb632c1534c993517bbeb3a25c012d2 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_dfcd2be3311feeefcf945ffeff5f201c = $(`&lt;div id=&quot;html_dfcd2be3311feeefcf945ffeff5f201c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Chai Nation&lt;/div&gt;`)[0];
#                 popup_9eb632c1534c993517bbeb3a25c012d2.setContent(html_dfcd2be3311feeefcf945ffeff5f201c);
#
#
#
#         marker_c6d8c2f5cb3c67805d65f0329be8fc8b.bindPopup(popup_9eb632c1534c993517bbeb3a25c012d2)
#         ;
#
#
#
#
#             var marker_169946278b0473c89684c1e217ad8cd8 = L.marker(
#                 [19.38344005, 72.83043446],
